# %%
import numpy as np
import pandas as pd
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_auc_score

# %%
item_info_train = pd.read_csv('ItemInfo_train.csv/ItemInfo_train.csv')
item_pairs_train = pd.read_csv('ItemPairs_train.csv/ItemPairs_train.csv')
item_info_test = pd.read_csv('ItemInfo_test.csv/ItemInfo_test.csv')
item_pairs_test  = pd.read_csv('ItemPairs_test.csv/ItemPairs_test.csv')
category = pd.read_csv('Category.csv/Category.csv')
location  = pd.read_csv('Location.csv/Location.csv')

# %%
def prepare_train_test(df_info, df_pairs):
    merge_1 = pd.merge(left=df_pairs, right=df_info, left_on='itemID_1', right_on='itemID',how='inner')
    merge_2 = pd.merge(left=merge_1, right=df_info,left_on='itemID_2', right_on='itemID',how='inner')
    merge_2.drop(['itemID_x','images_array_x','itemID_y','images_array_y'],axis = 1,inplace=True)
    return(merge_2)

# %% [markdown]
# ### Preparing train & test

# %%
train = prepare_train_test(item_info_train,item_pairs_train)
test = prepare_train_test(item_info_test,item_pairs_test)

# %% [markdown]
# ### Handling missing values

# %%
def missing_values(df):
    df.title_x.dropna(inplace=True)
    df.description_x.fillna(value=pd.Series(test.title_x.values),inplace=True)
    df.description_y.fillna(value=pd.Series(test.title_y.values),inplace=True)
    df.drop(['images_array_x','attrsJSON_x','price_x','images_array_y','attrsJSON_y','price_y'],axis=1,inplace=True)
    return(df)

# %%
def feature_add(df):
    df['title_len_x'] = [len(str(m)) for m in df.title_x.values]
    df['description_len_x'] = [len(str(m)) for m in df.description_x.values]
    df['title_len_y'] = [len(str(m)) for m in df.title_x.values]
    df['description_len_y'] = [len(str(m)) for m in df.description_y.values]
    df.drop(['title_x','title_y','description_x','description_y'],axis=1,inplace=True)
    return(df)

# %%
train = missing_values(train)
test = missing_values(test)

# %%
train = feature_add(train)
test = feature_add(test)

# %%
train.head(2)
# Out:
#    itemID_1  itemID_2  generationMethod  categoryID_x  locationID_x  \
# 0         1   4112648                 1            81        648140
# 1         3   1991275                 1            14        639040
#
#        lat_x      lon_x  categoryID_y  locationID_y      lat_y      lon_y  \
# 0  64.686946  30.815924            81        648140  64.686946  30.815924
# 1  55.678037  37.256548            14        639040  55.678037  37.256548
#
#    title_len_x  title_len_y  description_len_x  description_len_y
# 0           28           28                  7                  7
# 1            9            9                  7                  7

# %% [markdown]
# ### Training random forest on train dataset

# %%
rfc=RandomForestClassifier(n_estimators=1000)

# %%
y = train.isDuplicate
train.drop('isDuplicate',axis=1,inplace=True)

# %%
rfc.fit(train,y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc.feature_importances_
# Out:
# array([ 0.07861288,  0.0864356 ,  0.18976509,  0.0588853 ,  0.02623861,
#         0.04123123,  0.03872553,  0.05885876,  0.02667046,  0.04126645,
#         0.03927381,  0.05634325,  0.09657453,  0.05672616,  0.10439235])

# %%
rfc.classes_
# Out:
# array([0, 1], dtype=int64)

# %%
preds = rfc.predict_proba(test)[:,1]

# %%
submit = pd.DataFrame({'id':item_pairs_test.id.values,'probability':preds})

# %%
submit.to_csv('submit_28th_02.csv',index=None, header=True)

# %% [markdown]
# ### Generating some more features

# %%
item_info_train = pd.read_csv('ItemInfo_train.csv/ItemInfo_train.csv')
item_pairs_train = pd.read_csv('ItemPairs_train.csv/ItemPairs_train.csv')
item_info_test = pd.read_csv('ItemInfo_test.csv/ItemInfo_test.csv')
item_pairs_test  = pd.read_csv('ItemPairs_test.csv/ItemPairs_test.csv')
category = pd.read_csv('Category.csv/Category.csv')
location  = pd.read_csv('Location.csv/Location.csv')

# %%
train = prepare_train_test(item_info_train,item_pairs_train)
test = prepare_train_test(item_info_test,item_pairs_test)

# %%
train.drop(['generationMethod','images_array_x', 'attrsJSON_x','images_array_y', 'attrsJSON_y'], axis=1,inplace=True)

# %%
test.drop(['id', 'images_array_x','attrsJSON_x', 'images_array_y','attrsJSON_y'],axis=1,inplace=True)

# %%
train['latitude_same'] = (train.lat_x == train.lat_y).astype(int)
train['longitude_same'] = (train.lon_x == train.lon_y).astype(int)
train['location_same'] = (train.locationID_x == train.locationID_y).astype(int)
train['price_minus'] = (train.price_x - train.price_y)
train['title_same'] = (train.title_x == train.title_y).astype(int)
train['description_same'] = (train.description_x == train.description_y).astype(int)
test['latitude_same'] = (test.lat_x == test.lat_y).astype(int)
test['longitude_same'] = (test.lon_x == test.lon_y).astype(int)
test['location_same'] = (test.locationID_x == test.locationID_y).astype(int)
test['price_minus'] = (test.price_x - test.price_y)
test['title_same'] = (test.title_x == test.title_y).astype(int)
test['description_same'] = (test.description_x == test.description_y).astype(int)

test.fillna(value=-999,inplace=True)
train.fillna(value=-999,inplace=True)
# Out:
#          itemID_1  itemID_2  isDuplicate  categoryID_x  \
# 0               1   4112648            1            81
# 1               3   1991275            1            14
# 2               4   1223296            0            84
# 3               7   1058851            1            84
# 4               8   2161930            1            39
# 5               9    694103            1            39
# 6              12   5637025            0             9
# 7          401724   5637025            1             9
# 8         5279740   5637025            1             9
# 9              12   5279740            0             9
# 10        4721374   5279740            1             9
# 11             15    113701            0            32
# 12             16   2467698            0            27
# 13             19   4538621            0            88
# 14             19    380482            1            88
# 15             20   3737377            0            27
# 16        1298192   3737377            0            27
# 17             20   4117359            0            27
# 18        1298192   4117359            0            27
# 19             20   2338340            0            27
# 20        1298192   2338340            0            27
# 21             21   3276771            1            29
# 22        1211996   3276771            1            29
# 23             22   2719041            1            27
# 24             26   3226871            1            33
# 25             26   3913671            0            33
# 26             28   1356437            1            27
# 27             29   1959141            1             9
# 28             32   4156631            1            27
# 29             33    512178            0            84
# ...           ...       ...          ...           ...
# 2991366   6076531   6111582            1            84
# 2991367   6076853   6100159            1            19
# 2991368   6077323   6107400            1            24
# 2991369   6077717   6103751            1            39
# 2991370   6079457   6092804            1            14
# 2991371   6079902   6084541            1            20
# 2991372   6079906   6101207            1           112
# 2991373   6080669   6109092            1             9
# 2991374   6080999   6105015            0            84
# 2991375   6081022   6093209            1            19
# 2991376   6081070   6106029            1            10
# 2991377   6081856   6095264            1            10
# 2991378   6084482   6110469            1           112
# 2991379   6085309   6100334            1            20
# 2991380   6086029   6087019            1            10
# 2991381   6086278   6105989            0            83
# 2991382   6088419   6095401            1            85
# 2991383   6089096   6092147            1           114
# 2991384   6089354   6094569            0            29
# 2991385   6089405   6111381            1            27
# 2991386   6089990   6099615            0            88
# 2991387   6090665   6111628            1            27
# 2991388   6096767   6098116            0            82
# 2991389   6097921   6099438            1            24
# 2991390   6098593   6104890            1           114
# 2991391   6100664   6101171            0            10
# 2991392   6101234   6105511            0           112
# 2991393   6101382   6109873            0            24
# 2991394   6104879   6111227            1            36
# 2991395   6106239   6109219            1           105
#
#                                                    title_x  \
# 0                                        Продам Камаз 6520
# 1                                                Yamaha r6
# 2                                           iPhone 3gs 8gb
# 3                      Xiaomi Mi4 3гб RAM + 16гб ROM белый
# 4                                           Лыжные ботинки
# 5                        Сноуборд ботинки Nitro Team 10 us
# 6                                        LADA Priora, 2015
# 7                                        LADA Priora, 2015
# 8                                        LADA Priora, 2015
# 9                                        LADA Priora, 2015
# 10                                       LADA Priora, 2015
# 11                                               Телевизор
# 12                                          Шуба мутоновая
# 13                             Массажная накидка Beurer mg
# 14                             Массажная накидка Beurer mg
# 15                  Новые. Белоснежные. Идеальное качество
# 16                    Новое, белоснежное, кружевное платье
# 17                  Новые. Белоснежные. Идеальное качество
# 18                    Новое, белоснежное, кружевное платье
# 19                  Новые. Белоснежные. Идеальное качество
# 20                    Новое, белоснежное, кружевное платье
# 21                                            2 пары обуви
# 22                                                    Еcco
# 23                                   Продаю вечерние туфли
# 24                                                 Вьетнам
# 25                                                 Вьетнам
# 26                                              Полупальто
# 27                                      Daewoo Matiz, 2008
# 28                                     Пальто демисезонное
# 29         Дисплей Nokia Lumia+ тачскрин с рамкой оригинал
# ...                                                    ...
# 2991366            iPhone 5 white 16 gb комплект документы
# 2991367                          Коксовая мелочь км (0-10)
# 2991368                      1-к квартира, 42 м², 7/17 эт.
# 2991369                                             Скамья
# 2991370                          Скутер Suzuki let"s 2 new
# 2991371   Мягкий плед длинноворсный бамбук Евро + Доставка
# 2991372                                 Повар мясного цеха
# 2991373                                  Ford Mondeo, 2002
# 2991374                              Samsung galaxy note 2
# 2991375                                          Утепление
# 2991376  2016 супер мини-elm327 Bluetooth ELM 327 OBD2 OBD
# 2991377  Шины пара/комплект бу R15 195-65 Continental C...
# 2991378                                           Официант
# 2991379                                      Дачная мебель
# 2991380                 Зима Nokia WR R-17 235/55 2 колеса
# 2991381                             Крусанов Павел. Триада
# 2991382                                       Гараж, 26 м²
# 2991383               Все виды ремонта и отделки помещения
# 2991384                Новый джемпер "Свитбери" р-р122-128
# 2991385                            Converse женские черные
# 2991386           White Glo - система экспресс-отбеливания
# 2991387                           Комбинезон кожзам черный
# 2991388  Набор для приготовления шоколада "Рецепт Ацтеков"
# 2991389                     1-к квартира, 32 м², 11/12 эт.
# 2991390                                                Гнб
# 2991391                          Лада ВАЗ 2110 двери крыша
# 2991392                            Охранник, администратор
# 2991393                       2-к квартира, 51 м², 1/9 эт.
# 2991394                           Редкие банкноты СССР идт
# 2991395                                        Nikon D3100
#
#                                              description_x    price_x  \
# 0                                Продам Камаз 6520 20 тонн   300000.0
# 1                                          Весь в тюнинге.   300000.0
# 2        Телефон в хорошем состоянии, трещин и сколов н...     3500.0
# 3        Отличный подарок на новый год от "китайской ap...    13500.0
# 4            Лыжные ботинки в хорошем состоянии, 34 размер      500.0
# 5        сноубордические ботинки Nitro Team\nразмер 42,...     7000.0
# 6        Машина новая пробег реальный. Не битая не краш...   445000.0
# 7        Машина как с завода .( не битая , не крашеная,...   470000.0
# 8        Машина в идеальном состояний. Не битая не краш...   455000.0
# 2991392   Ищу работу, вахтой, за наличку.Удостоверение 4р.     1700.0
# 2991393  Внимание! В продаже 2-х комнатная квартира улу...     -999.0
# 2991394  Всё на фото,можно позвонить и уточнить.Можно в...     1000.0
# 2991395  Продам фотоаппарат в отличном состоянии!!! Пол...    12000.0
#
#          locationID_x      lat_x       lon_x        ...           price_y  \
# 0              648140  64.686946   30.815924        ...          300000.0
# 1              639040  55.678037   37.256548        ...          330000.0
# 2              640650  56.239398   43.460458        ...            3500.0
# 3              662210  55.777170   37.586194        ...           13500.0
# 4              624360  55.777170   37.586194        ...             600.0
# 5              644200  58.004785   56.237654        ...            7000.0
# 6              631060  44.219841   42.058825        ...          450000.0
# 7              631060  44.219841   42.058825        ...          450000.0
# 8              631060  44.219841   42.058825        ...          450000.0
# 9              631060  44.219841   42.058825        ...          455000.0
# 10             631060  44.219841   42.058825        ...          455000.0
# 11             662810  57.622434   39.887894        ...            5000.0
# 12             657600  56.495116   84.972128        ...            7500.0
# 13             637640  55.640538   37.606065        ...            6000.0
# 14             637640  55.640538   37.606065        ...            5900.0
# 15             661130  55.095626   59.963363        ...           13500.0
# 16             661130  55.095626   59.963363        ...           13500.0
# 17             661130  55.095626   59.963363        ...           13500.0
# 18             661130  55.095626   59.963363        ...           13500.0
# 19             661130  55.095626   59.963363        ...           13500.0
# 20             661130  55.095626   59.963363        ...           13500.0
# 21             662460  66.530937   66.602425        ...             500.0
# 22             662460  66.530937   66.602425        ...             500.0
# 23             635860  55.453085   65.346508        ...             690.0
# 24             646600  54.738437   55.983161        ...            -999.0
# 25             646600  54.738437   55.983161        ...            -999.0
# 26             630090  55.777170   37.586194        ...             800.0
# 27             624600  55.560530   42.038820        ...          150000.0
# 28             623430  50.584549   36.573676        ...             800.0
# 29             642320  54.990147   73.365319        ...            3000.0
# ...               ...        ...         ...        ...               ...
# 2991366        641780  55.030187   82.920534        ...           13000.0
# 2991367        658080  54.193802   37.619028        ...            8500.0
# 2991368        637950  55.556834   37.709097        ...           25000.0
# 2991369        623130  46.349474   48.031571        ...            2500.0
# 2991370        653240  59.932378   30.439351        ...           27000.0
# 2991371        653240  60.002427   30.296617        ...            1890.0
# 2991372        637640  55.758255   37.751583        ...           33000.0
# 2991373        625390  55.777170   37.586194        ...          175000.0
# 2991374        659020  57.182636   65.558421        ...            6490.0
# 2991375        646520  53.651622   55.962069        ...             150.0
# 2991376        641020  55.777170   37.586194        ...             450.0
# 2991377        637640  55.783195   37.719423        ...            7500.0
# 2991378        647420  42.983106   47.504978        ...            -999.0
# 2991379        646360  56.096463   54.274161        ...           12000.0
# 2991380        637640  55.854891   37.476231        ...            5000.0
# 2991381        653240  59.928893   30.411925        ...             600.0
# 2991382        658080  54.193802   37.619028        ...          205000.0
# 2991383        623220  55.777170   37.586194        ...             100.0
# 2991384        633540  45.034942   38.976032        ...             500.0
# 2991385        637640  55.836524   37.575558        ...            1600.0
# 2991386        637640  55.802988   37.744819        ...             705.0
# 2991387        630090  54.710303   20.510784        ...            1200.0
# 2991388        652430  54.619886   39.744954        ...            1390.0
# 2991389        625390  59.223011   39.883851        ...         1151500.0
# 2991390        634450  43.582684   39.722154        ...            3500.0
# 6                    1      -5000.0           1                 0
# 7                    1      20000.0           1                 0
# 8                    1       5000.0           1                 0
# 9                    1     -10000.0           1                 0
# 10                   1      10000.0           1                 0
# 11                   1      -3400.0           0                 0
# 12                   1      -6500.0           0                 0
# 13                   1      -1000.0           0                 0
# 14                   1       -900.0           0                 0
# 15                   1       1000.0           0                 0
# 16                   1       1000.0           0                 0
# 17                   1       1000.0           0                 0
# 18                   1       1000.0           0                 0
# 19                   0       1000.0           0                 0
# 20                   0       1000.0           0                 0
# 21                   1        200.0           0                 0
# 22                   1          0.0           0                 0
# 23                   1          0.0           0                 0
# 24                   1       -999.0           0                 0
# 25                   1       -999.0           0                 0
# 26                   1          0.0           0                 0
# 27                   1     -20000.0           1                 0
# 28                   1          0.0           0                 0
# 29                   1      -1200.0           0                 0
# ...                ...          ...         ...               ...
# 2991366              1        500.0           1                 0
# 2991367              1          0.0           1                 0
# 2991368              1          0.0           0                 0
# 2991369              1          0.0           0                 0
# 2991370              1      -2000.0           0                 0
# 2991371              1          0.0           0                 0
# 2991372              1          0.0           1                 1
# 2991373              1          0.0           1                 0
# 2991374              1       1500.0           0                 0
# 2991375              0          0.0           1                 0
# 2991376              1          0.0           0                 0
# 2991377              1        500.0           1                 0
# 2991378              1       -999.0           1                 1
# 2991379              1      -2000.0           0                 0
# 2991380              1      -1000.0           0                 0
# 2991381              1       -250.0           0                 0
# 2991382              1          0.0           1                 0
# 2991383              0          0.0           0                 1
# 2991384              1          0.0           0                 0
# 2991385              1          0.0           0                 0
# 2991386              1         -5.0           0                 0
# 2991387              1          0.0           0                 1
# 2991388              1       -100.0           0                 0
# 2991389              1      -3500.0           0                 0
# 2991390              1      -1000.0           0                 0
# 2991391              1       -999.0           0                 0
# 2991392              1        100.0           1                 0
# 2991393              1       -999.0           0                 0
# 2991394              1       -999.0           0                 0
# 2991395              1      -3000.0           1                 1
#
# [2991396 rows x 23 columns]

# %%
features = ['latitude_same', 'longitude_same', 'location_same', 'price_minus', 'title_same', 'description_same']

# %%
rfc.fit(train[features],train.isDuplicate.values)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc.feature_importances_
# Out:
# array([ 0.02424023,  0.01915796,  0.01352403,  0.62765799,  0.29355183,
#         0.02186796])

# %%
rfc.classes_
# Out:
# array([0, 1], dtype=int64)

# %%
preds_100=rfc.predict_proba(test[features])[:,1]

# %%
submit = pd.DataFrame({'id':item_pairs_test.id.values,'probability':preds_100})

# %%
submit.to_csv('submit_28_04.csv',index=False,header=True)

# %% [markdown]
# ### Applying GBM

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbm = GradientBoostingClassifier(n_estimators=1000)

# %%
gbm.fit(train[features], train.isDuplicate.values)

# %% [markdown]
# ### Creating new feature from json column using key-value comparison

# %%
item_info_train = pd.read_csv('ItemInfo_train.csv/ItemInfo_train.csv')
item_pairs_train = pd.read_csv('ItemPairs_train.csv/ItemPairs_train.csv')
item_info_test = pd.read_csv('ItemInfo_test.csv/ItemInfo_test.csv')
item_pairs_test  = pd.read_csv('ItemPairs_test.csv/ItemPairs_test.csv')
category = pd.read_csv('Category.csv/Category.csv')
location  = pd.read_csv('Location.csv/Location.csv')

# %%
train = prepare_train_test(item_info_train,item_pairs_train)
test = prepare_train_test(item_info_test,item_pairs_test)
